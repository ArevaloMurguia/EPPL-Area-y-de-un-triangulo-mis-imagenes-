# %% [markdown]
# <a href="https://colab.research.google.com/github/ArevaloMurguia/EPPL-Area-y-de-un-triangulo-mis-imagenes-/blob/main/EPPL_UII_Act_11_DF_%2B_codigo_Python_Arevalo_Rafael_0031.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Arevalo Rafael NL = 3 Fecha 25/0326
# ---
# ### Calcular el Area de un Triangulo
# ![Area triangulo rectangulo.jpg](data:image/jpeg;base64,...)
#
# ### Formula para calcular el Area
# A = (b * h) / 2
#
# ### Diagrama de flujo Lucichat
# ![Lucichat Rafael.PNG](data:image/png;base64,...)

# %%
# Calcular Area de un triangulo rectangulo
# Variables A, b, h
# Formula A = (b * h) / 2

print("Calcular Area de un triangulo rectangulo")

b = float(input("Ingrese la base: "))
h = float(input("Ingrese la altura: "))

A = (b * h) / 2

print("El area del triangulo es: ", A)
print("Arevalo Rafael NL = 3")
# Out:
# Calcular Area de un triangulo rectangulo
# Ingrese la base: 10
# Ingrese la altura: 20
# El area del triangulo es:  100.0
# Arevalo Rafael NL = 3

# %% [markdown]
# ### Relacion entre codigo y DF en Tldraw
# ![Tldraw Rafael Arevalo.PNG](data:image/png;base64,...)
